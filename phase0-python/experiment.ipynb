# %%
import httpx
data = httpx.get("https://httpbingo.org/json").json()

# %%
print(data["slideshow"])
# Out:
# {'author': 'Yours Truly', 'date': 'date of publication', 'slides': [{'title': 'Wake up to WonderWidgets!', 'type': 'all'}, {'items': ['Why <em>WonderWidgets</em> are great', 'Who <em>buys</em> WonderWidgets'], 'title': 'Overview', 'type': 'all'}], 'title': 'Sample Slide Show'}

# %%
print(data["slideshow"]["author"])
# Out:
# Yours Truly

# %%
import explore_utils
print(explore_utils.extract_author(data))
print(explore_utils.summarize_slideshow(data))
# Out:
# Yours Truly
# {'author': 'Yours Truly', 'date': 'date of publication', 'slides': [{'title': 'Wake up to WonderWidgets!', 'type': 'all'}, {'items': ['Why <em>WonderWidgets</em> are great', 'Who <em>buys</em> WonderWidgets'], 'title': 'Overview', 'type': 'all'}], 'title': 'Sample Slide Show'}
